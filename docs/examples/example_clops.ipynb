# %% [markdown]
# # Circuit Layer Operations Per Second (CLOPS)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Set IQM Token if using Resonance

# %%
# import os
# os.environ["IQM_TOKEN"] = "xxxxxxxxxxxxxxx"

# %% [markdown]
# ## Choose (or define) a backend

# %%
#backend = "fakeadonis"
#backend = "fakeapollo"
backend = "garnet"
#backend = "deneb"

# %% [markdown]
# ## CLOPS Configuration

# %%
from iqm.benchmarks.quantum_volume.clops import *

# %%
EXAMPLE_CLOPS = CLOPSConfiguration(
    qubits=[9, 14, 15, 17, 18, 19],
    num_circuits=100, # By definition set to 100
    num_updates=10, # By definition set to 10
    num_shots=100, # By definition set to 100
    calset_id=None,
)

# %% [markdown]
# ## Run the experiment

# %%
benchmark_clops = CLOPSBenchmark(backend, EXAMPLE_CLOPS)
run_clops = benchmark_clops.run()

# %% [markdown]
# ## Perform Analysis

# %%
result_clops = benchmark_clops.analyze()

# %% [markdown]
# ### List all the keys in the attributes of the dataset

# %%
for k in run_clops.dataset.attrs.keys():
    print(k)

# %%
run_clops.dataset.attrs["operation_counts"]

# %% [markdown]
# ### The observation object contains the benchmark results

# %%
result_clops.observations

# %% [markdown]
# ### Generate plots

# %% [markdown]
# The plot generated by the CLOPS analysis is a bar plot that shows a breakdown of elapsed times in the experiment in units of seconds.
#
# The bars labeled as "Remote" refer to time spent in the remote components of the experiment, as reported by the backend.
# - Remote (components) shows the values of the time spent in compilation, submission and execution of the jobs.
# - Remote (total) shows the total time spent in the remote components of the experiment.
#
# NB: the difference between the Remote "total" and "components" elapsed times may be due to other aspects like loading and storing jobs and IDs, etc.
#
# The "Wall-time" bars show time spent in the experiment as experienced by the user. NB: The time spent in assigning parameters is not included in the CLOPS value, since this is done offline in your (the user's) hardware.
# - Wall-time (CLOPS) encompasses the time related to the CLOPS value, i.e., comprising only of submitting jobs per template and retrieving the results, without time spent in transpilation or parameter assignment, which are both done offline.
# - Wall-time (total) shows a breakdown of the total wall-time of the experiment, with the added offline times of transpilation of circuit templates and assignment of parameters.
#
# NB: The difference between the "user retrieve" time and the Remote "total" time can be assigned as a latency time, and may vary significantly depending on external circumstances. This latency is the aggregated time between when a job is finished and when the results are received (which may be due to several external factors).

# %%
result_clops.plot_all()

# %% [markdown]
# # CLOPS_H experiment

# %%
from iqm.benchmarks.quantum_volume.clops_h import *

# %%
import os
from iqm.qiskit_iqm import IQMProvider
iqm_server_url = "https://cocos.resonance.meetiqm.com/garnet"
os.environ[
    "IQM_TOKEN"
] = ""
provider = IQMProvider(iqm_server_url)
backend = provider.get_backend()

# %%
EXAMPLE_CLOPSH = CLOPSHConfiguration(
            qubits=list(range(2)),
            num_circuits=100,  # By definition set to 5000
            num_layers=100,  # By definition set to 100
            num_shots=100,  # By definition set to 100
            max_circuits_per_batch = 10,
            calset_id=None,
            routing_method="sabre",
            physical_layout="fixed",
        )

# %%
benchmark = CLOPSHBenchmark(backend, EXAMPLE_CLOPSH)
benchmark.run()
result = benchmark.analyze()
# Out:
# 2025-11-19 10:53:26,851 - iqm.benchmarks.logging_config - INFO - NB: CLOPS parameters, by definition, are [num_circuits=1000, num_layers=100, num_shots=100] You chose [num_circuits=100, num_layers=100, num_shots=100].
# 2025-11-19 10:53:26,852 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 1 / 10
# 2025-11-19 10:53:27,465 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 1 / 10
# 2025-11-19 10:53:27,466 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:27,713 - iqm.benchmarks.logging_config - INFO - Submitting batch 1 / 10 with 10 circuits
# 2025-11-19 10:53:27,714 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:30,103 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 2 / 10
# 2025-11-19 10:53:30,175 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 2 / 10
# 2025-11-19 10:53:30,177 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:30,427 - iqm.benchmarks.logging_config - INFO - Submitting batch 2 / 10 with 10 circuits
# 2025-11-19 10:53:30,428 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:33,261 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 3 / 10
# 2025-11-19 10:53:33,323 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 3 / 10
# 2025-11-19 10:53:33,323 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:33,538 - iqm.benchmarks.logging_config - INFO - Submitting batch 3 / 10 with 10 circuits
# 2025-11-19 10:53:33,549 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:35,056 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 4 / 10
# 2025-11-19 10:53:35,140 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 4 / 10
# 2025-11-19 10:53:35,142 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:35,368 - iqm.benchmarks.logging_config - INFO - Submitting batch 4 / 10 with 10 circuits
# 2025-11-19 10:53:35,370 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:37,540 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 5 / 10
# 2025-11-19 10:53:37,603 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 5 / 10
# 2025-11-19 10:53:37,605 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:37,816 - iqm.benchmarks.logging_config - INFO - Submitting batch 5 / 10 with 10 circuits
# 2025-11-19 10:53:37,830 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:39,850 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 6 / 10
# 2025-11-19 10:53:39,905 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 6 / 10
# 2025-11-19 10:53:39,921 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:40,131 - iqm.benchmarks.logging_config - INFO - Submitting batch 6 / 10 with 10 circuits
# 2025-11-19 10:53:40,131 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:42,308 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 7 / 10
# 2025-11-19 10:53:42,375 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 7 / 10
# 2025-11-19 10:53:42,375 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:42,597 - iqm.benchmarks.logging_config - INFO - Submitting batch 7 / 10 with 10 circuits
# 2025-11-19 10:53:42,597 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:44,989 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 8 / 10
# 2025-11-19 10:53:45,058 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 8 / 10
# 2025-11-19 10:53:45,058 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:45,271 - iqm.benchmarks.logging_config - INFO - Submitting batch 8 / 10 with 10 circuits
# 2025-11-19 10:53:45,272 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:47,178 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 9 / 10
# 2025-11-19 10:53:47,259 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 9 / 10
# 2025-11-19 10:53:47,259 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:47,475 - iqm.benchmarks.logging_config - INFO - Submitting batch 9 / 10 with 10 circuits
# 2025-11-19 10:53:47,475 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:49,550 - iqm.benchmarks.logging_config - INFO - Generating 10 parametrized circuit templates for batch 10 / 10
# 2025-11-19 10:53:49,614 - iqm.benchmarks.logging_config - INFO - Transpiling 10 circuits on qubits [0, 1] for batch 10 / 10
# 2025-11-19 10:53:49,614 - iqm.benchmarks.logging_config - INFO - Transpiling for backend IQM Backend with optimization level 0, sabre routing method all circuits
# 2025-11-19 10:53:49,831 - iqm.benchmarks.logging_config - INFO - Submitting batch 10 / 10 with 10 circuits
# 2025-11-19 10:53:49,831 - iqm.benchmarks.logging_config - INFO - Submitting batch with 10 circuits corresponding to qubits [0, 1]
# C:\Users\RaphaelBrieger\.local\share\mamba\envs\benchmarks_new\Lib\site-packages\iqm\qiskit_iqm\iqm_provider.py:193: UserWarning: Unknown backend option(s): {'calibration_set_id': None}
#   warnings.warn(f"Unknown backend option(s): {unknown_options}")
# 2025-11-19 10:53:51,847 - iqm.benchmarks.logging_config - INFO - Retrieving counts
# 2025-11-19 10:53:51,847 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:53:52,838 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:53:53,924 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:53:55,560 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:54:04,686 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:54:07,436 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:54:08,971 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:54:11,092 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:54:15,425 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:54:16,679 - iqm.benchmarks.logging_config - INFO - Retrieving all counts
# 2025-11-19 10:54:18,115 - iqm.benchmarks.logging_config - INFO - Total elapsed times from job execution metadata:
# 2025-11-19 10:54:18,115 - iqm.benchmarks.logging_config - INFO - 	"job_total": 0.00 sec
# 2025-11-19 10:54:18,115 - iqm.benchmarks.logging_config - INFO - 	"compile_total": 27.94 sec
# 2025-11-19 10:54:18,115 - iqm.benchmarks.logging_config - INFO - 	"post_processing_total": 8.24 sec
# 2025-11-19 10:54:18,115 - iqm.benchmarks.logging_config - INFO - 	"execution_total": 10.93 sec
# 2025-11-19 10:54:18,115 - iqm.benchmarks.logging_config - INFO - 	"clops_time": 0.00 sec
